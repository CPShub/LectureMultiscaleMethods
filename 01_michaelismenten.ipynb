# %%
######################################
# Run First Cell for Initialization  #
#                                    #
#           SHIFT + ENTER            #
######################################

# Initialize notebook
# %run -i ./code/01_michaelismenten/p_01_initialize
# Load functions in external python scripts
# %load_ext autoreload
# %autoreload 1
# %aimport refresh
# %aimport p_01_ode

display(Javascript("Jupyter.notebook.execute_cells([2,3])"))

# %% [markdown]
# Nonlinear ODE model:
# \begin{equation}
# \frac{d}{dt}
# \begin{bmatrix}
#    y_1 \\
#    y_2
# \end{bmatrix}=
# \begin{bmatrix}
#    -y_1+\left(y_1+\kappa-\lambda\right)y_2 \\
#    \frac{1}{\varepsilon}\left(y_1-\left(y_1+\kappa\right)y_2\right)
#    \end{bmatrix}
# \end{equation}
#
# Macro model solution:
# \begin{equation}
# y_2=\frac{y_1}{y_1+\kappa}
# \end{equation}

# %%
# %run -i ./code/01_michaelismenten/p_01_input
# Out:
# interactive(children=(FloatSlider(value=1.0, description='y_1_0', max=2.51, step=0.5), FloatSlider(value=1.0, …
# Button(description='Refresh', style=ButtonStyle())

# %%
p_01_ode.eval_y1_y2(list(w.result.values()))
# Out:
# y_1_0: 1.00, y_2_0: 1.00
# kappa: 1.00, lambda: 2.00
# epsilon: 0.10
