# %% [markdown]
# # Analytical methods - bounds and approximations
#
# Created by: Dr. Mauricio Fernández
#
# Contact: fernandez@cps.tu-darmstadt.de
#
# Date of creation: 2020-05-10
#
# Last update: 2020-05-10

# %% [markdown]
# **Information:**
# Run the following cell to define all commands for this notebook.

# %%
# %run -i ./code/04_analytical_methods/main

# %% [markdown]
# ## Description
#
# In this notebook, bounds and approximations for the isotropic effetive stiffness $\mathbb{C}^*$ of isotropic 2-phase linear elastic materials will be presented. Static and interactive content is offered to visualize and explore the behavior of the presented bounds and approximations.
#
# The content and notation follows the corresponding tutorial of the course. An isotropic stiffness is represented as $\mathbb{C} = \mathrm{iso}(c_1,c_2) = c_1 \mathbb{P}_1 + c_2 \mathbb{P}_2$ and has the eigenvalues $c_1 = 3 K$ and $c_2 = 2 G$, where $K$ and $G$ correspond to the compression and shear modulus of the material. The volume fraction of material 2 is denoted as $f^{(2)} \in [0,1]$.

# %% [markdown]
# ## Static content

# %%
show_static_plot()
# Out:
# Static plot
# Material 1 eigenvalues:
# [ 10 100]
# Material 2 eigenvalues:
# [80 30]

# %% [markdown]
# ## Interactive content
#
# For INTERACTIVE content, you will have to
# * either download the notebook, have installed Python 3 and all required packages
# * or open up the repository online through Binder, specially for smartphones, see README of repository.

# %%
start_interactive()
# Out:
# interactive(children=(Dropdown(description='Select device', options=(('', 0), ('computer', 1), ('smartphone', …
